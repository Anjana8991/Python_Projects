# %%
import pandas as pd
import sys 
print(sys.version)
print(sys.executable)
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("ran_kpi_data.csv")
# Convert Date column to datetime format
df["Date & Time"] = pd.to_datetime(df["Date & Time"])
print("First few rows of the dataset:")
print(df.head())
plt.figure(figsize=(12,6))
sns.lineplot(x=df["Date & Time"],y=df["Call Drop Rate (%)"],marker ="o",label ="CDR")
plt.xlabel("Date & Time")
plt.ylabel("Call Drop Rate (%)")
plt.title("Call Drop Rate Over Time")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# kPI Correlation Analysis
correlation_matrix = df[["Call Drop Rate (%)","Handover Failure Rate (%)","Network Load (%)","RSRP","SINR"]].corr()
sns.heatmap(correlation_matrix,annot=True,cmap="coolwarm",linewidths=0.5)
plt.title("KPI Correlation Analysis")
plt.show()
# Out:
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# C:\Users\anjan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe
# First few rows of the dataset:
#           Date & Time  Call Drop Rate (%)  Handover Failure Rate (%)  RSRP  \
# 0 2024-02-01 00:00:00                 1.2                        3.4   -95
# 1 2024-02-01 01:00:00                 1.0                        3.0   -96
# 2 2024-02-01 02:00:00                 1.5                        4.2   -94
# 3 2024-02-01 03:00:00                 2.0                        5.1   -97
# 4 2024-02-01 04:00:00                 2.5                        6.2   -98
#
#    SINR  Network Load (%)
# 0    15                50
# 1    14                48
# 2    16                55
# 3    13                60
# 4    12                65

# %%
# !pip install seaborn

# %%
import sys
print("Python Version:", sys.version)
print("Python Executable:", sys.executable)
# Out:
# Python Version: 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# Python Executable: C:\Users\anjan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe
